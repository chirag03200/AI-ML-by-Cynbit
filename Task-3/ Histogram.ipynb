# %% [markdown]
# ## Histogram

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
def calculate_results(marks):
   total = sum(marks)
   average = total/len(marks)

   if average >= 90:
       grade = 'A'
   elif average>= 75:
       grade = 'B'
   else:
       grade = 'C'

   return total, average, grade

# input number of sturdents
stu_num = int(input("Number of students: "))

data = []
# loop for input marks
for i in range(stu_num):
    name = input("Name :")
    print(f"\n enter the marks of student{i+1}: ")
    s1 = float(input("Subject 1 marks: "))
    s2 = float(input("Subject 2 marks: "))
    s3 = float(input("Subject 3 marks: "))
    print("\n")
    total, avg, grade = calculate_results([s1, s2, s3])

    print(f"\nReport for {name}:")
    print(f"Total: {total}, Average: {avg:.2f}, Grade: {grade}")

    #Store the data in a pandas DataFrame
    data.append({ "Name":name, "Subject 1": s1,"Subject 2": s2,"Subject 3": s3,
                 "Total": total, "Average": avg, "Grade": grade})

df = pd.DataFrame(data)
print("\n📋 Student Report Card:")
print(df)
# Out:
# Number of students:  4
# Name : AVANI
#  enter the marks of student1:
# Subject 1 marks:  78
# Subject 2 marks:  89
# Subject 3 marks:  87
# Report for AVANI:
# Total: 254.0, Average: 84.67, Grade: B
# Name : BUNTY
#  enter the marks of student2:
# Subject 1 marks:  88
# Subject 2 marks:  78
# Subject 3 marks:  78
# Report for BUNTY:
# Total: 244.0, Average: 81.33, Grade: B
# Name : RAMESH
#  enter the marks of student3:
# Subject 1 marks:  87
# Subject 2 marks:  99
# Subject 3 marks:  99
# Report for RAMESH:
# Total: 285.0, Average: 95.00, Grade: A
# Name : AALOK
#  enter the marks of student4:
# Subject 1 marks:  67
# Subject 2 marks:  67
# Subject 3 marks:  66
# Report for AALOK:
# Total: 200.0, Average: 66.67, Grade: C
#
# 📋 Student Report Card:
#      Name  Subject 1  Subject 2  Subject 3  Total    Average Grade
# 0   AVANI       78.0       89.0       87.0  254.0  84.666667     B
# 1   BUNTY       88.0       78.0       78.0  244.0  81.333333     B
# 2  RAMESH       87.0       99.0       99.0  285.0  95.000000     A
# 3   AALOK       67.0       67.0       66.0  200.0  66.666667     C

# %%
# Histogram of Total Marks
plt.figure(figsize=(8, 5))
plt.hist(df['Total'], bins=5, color='skyblue', edgecolor='black')
plt.title('Distribution of Total Marks')
plt.xlabel('Total Marks')
plt.ylabel('Number of Students')
plt.grid(True)
plt.show()

# %%
# Histogram of Average Marks
plt.figure(figsize=(8, 5))
plt.hist(df['Average'], bins=5, color='lightgreen', edgecolor='black')
plt.title('Distribution of Average Marks')
plt.xlabel('Average Marks')
plt.ylabel('Number of Students')
plt.grid(True)
plt.show()

# %% [markdown]
# ## with seaborn

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Total'], bins=5, kde=True, color='skyblue')
plt.title('Distribution of Total Marks')
plt.xlabel('Total Marks')
plt.ylabel('Number of Students')
plt.show()

# %%
# Histogram of Average Marks using seaborn
plt.figure(figsize=(8, 5))
sns.histplot(df['Average'], bins=5, kde=True, color='lightgreen')
plt.title('Distribution of Average Marks')
plt.xlabel('Average Marks')
plt.ylabel('Number of Students')
plt.show()
