# %% [markdown]
# ## Box Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
def calculate_results(marks):
   total = sum(marks)
   average = total/len(marks)

   if average >= 90:
       grade = 'A'
   elif average>= 75:
       grade = 'B'
   else:
       grade = 'C'

   return total, average, grade

# input number of sturdents
stu_num = int(input("Number of students: "))

data = []
# loop for input marks
for i in range(stu_num):
    name = input("Name :")
    print(f"\n enter the marks of student{i+1}: ")
    s1 = float(input("Subject 1 marks: "))
    s2 = float(input("Subject 2 marks: "))
    s3 = float(input("Subject 3 marks: "))
    print("\n")
    total, avg, grade = calculate_results([s1, s2, s3])

    print(f"\nReport for {name}:")
    print(f"Total: {total}, Average: {avg:.2f}, Grade: {grade}")

    #Store the data in a pandas DataFrame
    data.append({ "Name":name, "Subject 1": s1,"Subject 2": s2,"Subject 3": s3,
                 "Total": total, "Average": avg, "Grade": grade})

df = pd.DataFrame(data)
print("\n📋 Student Report Card:")
print(df)
# Out:
# Number of students:  4
# Name : A
#  enter the marks of student1:
# Subject 1 marks:  89
# Subject 2 marks:  88
# Subject 3 marks:  99
# Report for A:
# Total: 276.0, Average: 92.00, Grade: A
# Name : B
#  enter the marks of student2:
# Subject 1 marks:  76
# Subject 2 marks:  65
# Subject 3 marks:  56
# Report for B:
# Total: 197.0, Average: 65.67, Grade: C
# Name : C
#  enter the marks of student3:
# Subject 1 marks:  78
# Subject 2 marks:  8
# Subject 3 marks:  89
# Report for C:
# Total: 175.0, Average: 58.33, Grade: C
# Name : D
#  enter the marks of student4:
# Subject 1 marks:  78
# Subject 2 marks:  88
# Subject 3 marks:  78
# Report for D:
# Total: 244.0, Average: 81.33, Grade: B
#
# 📋 Student Report Card:
#   Name  Subject 1  Subject 2  Subject 3  Total    Average Grade
# 0    A       89.0       88.0       99.0  276.0  92.000000     A
# 1    B       76.0       65.0       56.0  197.0  65.666667     C
# 2    C       78.0        8.0       89.0  175.0  58.333333     C
# 3    D       78.0       88.0       78.0  244.0  81.333333     B

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(6, 6))
sns.boxplot(data=df[['Subject 1', 'Subject 2', 'Subject 3']], palette="pastel")
plt.title('Boxplot of Marks by Subject')
plt.ylabel('Marks')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Average'], color="lightgreen")
plt.title('Boxplot of Average Marks')
plt.xlabel('Average Marks')
plt.show()
