# %% [markdown]
# ## Bar plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# %%
### Function to calculate total average and grade 
def calculate_results(marks):
   total = sum(marks)
   average = total/len(marks)

   if average >= 90:
       grade = 'A'
   elif average>= 75:
       grade = 'B'
   else:
       grade = 'C'

   return total, average, grade

# input number of sturdents
stu_num = int(input("Number of students: "))

data = []
# loop for input marks
for i in range(stu_num):
    name = input("Name :")
    print(f"\n enter the marks of student{i+1}: ")
    s1 = float(input("Subject 1 marks: "))
    s2 = float(input("Subject 2 marks: "))
    s3 = float(input("Subject 3 marks: "))
    print("\n")
    total, avg, grade = calculate_results([s1, s2, s3])

    print(f"\nReport for {name}:")
    print(f"Total: {total}, Average: {avg:.2f}, Grade: {grade}")

    #Store the data in a pandas DataFrame
    data.append({ "Name":name, "Subject 1": s1,"Subject 2": s2,"Subject 3": s3,
                 "Total": total, "Average": avg, "Grade": grade})

df = pd.DataFrame(data)
print("\n📋 Student Report Card:")
print(df)
# Out:
# Number of students:  4
# Name : rahul
#  enter the marks of student1:
# Subject 1 marks:  99
# Subject 2 marks:  89
# Subject 3 marks:  89
# Report for rahul:
# Total: 277.0, Average: 92.33, Grade: A
# Name : avani
#  enter the marks of student2:
# Subject 1 marks:  89
# Subject 2 marks:  87
# Subject 3 marks:  88
# Report for avani:
# Total: 264.0, Average: 88.00, Grade: B
# Name : chetan
#  enter the marks of student3:
# Subject 1 marks:  98
# Subject 2 marks:  76
# Subject 3 marks:  78
# Report for chetan:
# Total: 252.0, Average: 84.00, Grade: B
# Name : himani
#  enter the marks of student4:
# Subject 1 marks:  6
# Subject 2 marks:  77
# Subject 3 marks:  89
# Report for himani:
# Total: 172.0, Average: 57.33, Grade: C
#
# 📋 Student Report Card:
#      Name  Subject 1  Subject 2  Subject 3  Total    Average Grade
# 0   rahul       99.0       89.0       89.0  277.0  92.333333     A
# 1   avani       89.0       87.0       88.0  264.0  88.000000     B
# 2  chetan       98.0       76.0       78.0  252.0  84.000000     B
# 3  himani        6.0       77.0       89.0  172.0  57.333333     C

# %%
 # Count the number of students for each grade
grade_counts = df['Grade'].value_counts().sort_index()

# Bar plot
plt.figure(figsize=(6, 5))
plt.bar(grade_counts.index, grade_counts.values, color=['r', 'y', 'b'],label = ['A','B','C'],)
plt.title("Number of Students per Grade")
plt.xlabel("Grade")
plt.ylabel("Number of Students")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bar plot with seaborn

# %%
import seaborn as sns

# %%
 grade_counts = df['Grade'].value_counts().reset_index()
grade_counts.columns = ['Grade', 'Count']

# Plot with hue as Grade and legend disabled
plt.figure(figsize=(6, 5))
sns.barplot(data=grade_counts, x='Grade', y='Count', hue='Grade', palette='Set2', legend=False)

plt.title('Number of Students per Grade')
plt.xlabel('Grade')
plt.ylabel('Number of Students')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
